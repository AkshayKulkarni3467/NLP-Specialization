# %%
faqs = """The major portion of the brain is the cerebrum, which divides the left and right cerebral hemispheres, both of which have numerous folds and convolutions present on their surface. 
Between these convolutions are ridges known as gyri. 
Small grooves that are present between the gyri are known as the plural of sulcus or sulci, whereas larger grooves are referred to as fissures.
The right and left cerebral hemispheres, both of which are covered in the cerebral cortex that is otherwise known as gray matter, are joined together by the corpus callosum. 
Whereas the left hemisphere controls speech and abstract thinking, the right hemisphere controls spatial thinking.
The frontal, parietal, temporal, and occipital lobes are the four lobes that make up the cerebrum. 
The frontal lobes, which are present directly behind the forehead, are the largest lobes of the human brain. 
The frontal lobes are primarily responsible for controlling language, motor function, and various cognitive processes including self-awareness, mood, affect, memory, attention, as well as both social and moral reasoning.
Within the frontal lobe is Broca’s area, which is responsible for speech production. 
The parietal lobes, who can be found near the center of the brain between the frontal and occipital lobes, are responsible for interpreting different sensory and memory functions.
The temporal lobes, which is commonly referred to as the neocortex, is located close to the base of the skull. 
Within the temporal lobe is the Wernicke area, which allows individuals to understand both spoken and written language. 
In addition to processing speech, the temporal lobe also processes sensory information that contributes to the retention of memories, languages, and emotions.
The fourth and final lobe of the cerebrum is the occipital lobe, which is the smallest lobe of the cerebrum and forms the caudal part of the brain. 
The primary function of the occipital lobe is the interpretation of visual information.The cerebellum and spinal cord are connected to the cerebral hemispheres by the brainstem. 
The brain stem can be classified into four distinct sections that include the diencephalon, midbrain, pons, and medulla oblongata. 
The diencephalon, which is the most superior portion of the brainstem, is further subdivided into four portions that include the epithalamus, subthalamus, hypothalamus, and thalamus.
The thalamus, which is the largest portion of the diencephalon, serves as a relay point for all sensory information that enters the cortex and eventually gets transmitted to the cerebrum for processing. 
The hypothalamus also processes incoming sensory information; however, all of the information processed by the hypothalamus is derived from the autonomic nervous system (ANS).
As a result, the hypothalamus maintains eating habits, sexual behavior, and sleep patterns in addition to maintaining an individual’s body temperature. 
Additionally, the secretions of the pituitary gland, which develops from a downward extension of the hypothalamus, is controlled by the hypothalamus.
The midbrain, which connects the diencephalon to the pons, controls ocular motion, whereas the pons is involved in the regulation of eye and facial movements, hearing and balance, as well as all sensory information processed by the facial nerves.
The medulla oblongata, which is located between the pons and the spinal cord and is therefore the most inferior portion of the brainstem, controls autonomic functions such as breathing, blood pressure, cardiac rhythms, and swallowing. 
Notably, brain death of patients in a clinical setting is declared when there is significant destruction of the medulla oblongata.

"""

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.text import Tokenizer

# %%
tokenizer = Tokenizer()

# %%
tokenizer.fit_on_texts([faqs])

# %%
len(tokenizer.word_index)
# Out:
# 232

# %%
input_sequences = []
for sentence in faqs.split('\n'):
  tokenized_sentence = tokenizer.texts_to_sequences([sentence])[0]

  for i in range(1,len(tokenized_sentence)):
    input_sequences.append(tokenized_sentence[:i+1])

# %%
input_sequences
# Out:
# [[1, 78],
#  [1, 78, 21],
#  [1, 78, 21, 3],
#  [1, 78, 21, 3, 1],
#  [1, 78, 21, 3, 1, 12],
#  [1, 78, 21, 3, 1, 12, 4],
#  [1, 78, 21, 3, 1, 12, 4, 1],
#  [1, 78, 21, 3, 1, 12, 4, 1, 15],
#  [1, 78, 21, 3, 1, 12, 4, 1, 15, 5],
#  [1, 78, 21, 3, 1, 12, 4, 1, 15, 5, 79],
#  [1, 78, 21, 3, 1, 12, 4, 1, 15, 5, 79, 1],
#  [1, 78, 21, 3, 1, 12, 4, 1, 15, 5, 79, 1, 31],
#  [1, 78, 21, 3, 1, 12, 4, 1, 15, 5, 79, 1, 31, 2],
#  [1, 78, 21, 3, 1, 12, 4, 1, 15, 5, 79, 1, 31, 2, 32],
#  [1, 78, 21, 3, 1, 12, 4, 1, 15, 5, 79, 1, 31, 2, 32, 22],
#  [1, 78, 21, 3, 1, 12, 4, 1, 15, 5, 79, 1, 31, 2, 32, 22, 33],
#  [1, 78, 21, 3, 1, 12, 4, 1, 15, 5, 79, 1, 31, 2, 32, 22, 33, 23],
#  [1, 78, 21, 3, 1, 12, 4, 1, 15, 5, 79, 1, 31, 2, 32, 22, 33, 23, 3],
#  [1, 78, 21, 3, 1, 12, 4, 1, 15, 5, 79, 1, 31, 2, 32, 22, 33, 23, 3, 5],
#  [1, 78, 21, 3, 1, 12, 4, 1, 15, 5, 79, 1, 31, 2, 32, 22, 33, 23, 3, 5, 80],
#  [1,
#   78,
#   21,
#   3,
#   1,
#   12,
#   4,
#   1,
#   15,
#   5,
#   79,
#   1,
#   31,
#   2,
#   32,
#   22,
#   33,
#   23,
#   3,
#   5,
#   80,
#   81],
#  [1,
#   78,
#   21,
#   3,
#   1,
#   12,
#   4,
#   1,
#   15,
#   5,
#   79,
#   1,
#   31,
#   2,
#   32,
#   22,
#   33,
#   23,
#   3,
#   5,
#   80,
#   81,
#   82],
#  [1,
#   78,
#   21,
#   3,
#   1,
#   12,
#   4,
#   1,
#   15,
#   5,
#   79,
#   1,
#   31,
#   2,
#   32,
#   22,
#   33,
#   23,
#   3,
#   5,
#   80,
#   81,
#   82,
#   2],
#  [1,
#   78,
#   21,
#   3,
#   1,
#   12,
#   4,
#   1,
#   15,
#   5,
#   79,
#   1,
#   31,
#   2,
#   32,
#   22,
#   33,
#   23,
#   3,
#   5,
#   80,
#   81,
#   82,
#   2,
#   45],
#  [1,
#   78,
#   21,
#   3,
#   1,
#   12,
#   4,
#   1,
#   15,
#   5,
#   79,
#   1,
#   31,
#   2,
#   32,
#   22,
#   33,
#   23,
#   3,
#   5,
#   80,
#   81,
#   82,
#   2,
#   45,
#   34],
#  [1,
#   78,
#   21,
#   3,
#   1,
#   12,
#   4,
#   1,
#   15,
#   5,
#   79,
#   1,
#   31,
#   2,
#   32,
#   22,
#   33,
#   23,
#   3,
#   5,
#   80,
#   81,
#   82,
#   2,
#   45,
#   34,
#   83],
#  [1,
#   78,
#   21,
#   3,
#   1,
#   12,
#   4,
#   1,
#   15,
#   5,
#   79,
#   1,
#   31,
#   2,
#   32,
#   22,
#   33,
#   23,
#   3,
#   5,
#   80,
#   81,
#   82,
#   2,
#   45,
#   34,
#   83,
#   84],
#  [1,
#   78,
#   21,
#   3,
#   1,
#   12,
#   4,
#   1,
#   15,
#   5,
#   79,
#   1,
#   31,
#   2,
#   32,
#   22,
#   33,
#   23,
#   3,
#   5,
#   80,
#   81,
#   82,
#   2,
#   45,
#   34,
#   83,
#   84,
#   85],
#  [24, 86],
#  [24, 86, 45],
#  [24, 86, 45, 6],
#  [24, 86, 45, 6, 87],
#  [24, 86, 45, 6, 87, 35],
#  [24, 86, 45, 6, 87, 35, 7],
#  [24, 86, 45, 6, 87, 35, 7, 46],
#  [88, 47],
#  [88, 47, 10],
#  [88, 47, 10, 6],
#  [88, 47, 10, 6, 34],
#  [88, 47, 10, 6, 34, 24],
#  [88, 47, 10, 6, 34, 24, 1],
#  [88, 47, 10, 6, 34, 24, 1, 46],
#  [88, 47, 10, 6, 34, 24, 1, 46, 6],
#  [88, 47, 10, 6, 34, 24, 1, 46, 6, 35],
#  [88, 47, 10, 6, 34, 24, 1, 46, 6, 35, 7],
#  [88, 47, 10, 6, 34, 24, 1, 46, 6, 35, 7, 1],
#  [88, 47, 10, 6, 34, 24, 1, 46, 6, 35, 7, 1, 89],
#  [88, 47, 10, 6, 34, 24, 1, 46, 6, 35, 7, 1, 89, 3],
#  [88, 47, 10, 6, 34, 24, 1, 46, 6, 35, 7, 1, 89, 3, 90],
#  [88, 47, 10, 6, 34, 24, 1, 46, 6, 35, 7, 1, 89, 3, 90, 91],
#  [88, 47, 10, 6, 34, 24, 1, 46, 6, 35, 7, 1, 89, 3, 90, 91, 92],
#  [88, 47, 10, 6, 34, 24, 1, 46, 6, 35, 7, 1, 89, 3, 90, 91, 92, 36],
#  [88, 47, 10, 6, 34, 24, 1, 46, 6, 35, 7, 1, 89, 3, 90, 91, 92, 36, 93],
#  [88, 47, 10, 6, 34, 24, 1, 46, 6, 35, 7, 1, 89, 3, 90, 91, 92, 36, 93, 47],
#  [88, 47, 10, 6, 34, 24, 1, 46, 6, 35, 7, 1, 89, 3, 90, 91, 92, 36, 93, 47, 6],
#  [88,
#   47,
#   10,
#   6,
#   34,
#   24,
#   1,
#   46,
#   6,
#   35,
#   7,
#   1,
#   89,
#   3,
#   90,
#   91,
#   92,
#   36,
#   93,
#   47,
#   6,
#   48],
#  [88,
#   47,
#   10,
#   6,
#   34,
#   24,
#   1,
#   46,
#   6,
#   35,
#   7,
#   1,
#   89,
#   3,
#   90,
#   91,
#   92,
#   36,
#   93,
#   47,
#   6,
#   48,
#   8],
#  [88,
#   47,
#   10,
#   6,
#   34,
#   24,
#   1,
#   46,
#   6,
#   35,
#   7,
#   1,
#   89,
#   3,
#   90,
#   91,
#   92,
#   36,
#   93,
#   47,
#   6,
#   48,
#   8,
#   7],
#  [88,
#   47,
#   10,
#   6,
#   34,
#   24,
#   1,
#   46,
#   6,
#   35,
#   7,
#   1,
#   89,
#   3,
#   90,
#   91,
#   92,
#   36,
#   93,
#   47,
#   6,
#   48,
#   8,
#   7,
#   94],
#  [1, 32],
#  [1, 32, 2],
#  [1, 32, 2, 31],
#  [1, 32, 2, 31, 22],
#  [1, 32, 2, 31, 22, 33],
#  [1, 32, 2, 31, 22, 33, 23],
#  [1, 32, 2, 31, 22, 33, 23, 3],
#  [1, 32, 2, 31, 22, 33, 23, 3, 5],
#  [1, 32, 2, 31, 22, 33, 23, 3, 5, 6],
#  [1, 32, 2, 31, 22, 33, 23, 3, 5, 6, 95],
#  [1, 32, 2, 31, 22, 33, 23, 3, 5, 6, 95, 16],
#  [1, 32, 2, 31, 22, 33, 23, 3, 5, 6, 95, 16, 1],
#  [1, 32, 2, 31, 22, 33, 23, 3, 5, 6, 95, 16, 1, 22],
#  [1, 32, 2, 31, 22, 33, 23, 3, 5, 6, 95, 16, 1, 22, 49],
#  [1, 32, 2, 31, 22, 33, 23, 3, 5, 6, 95, 16, 1, 22, 49, 10],
#  [1, 32, 2, 31, 22, 33, 23, 3, 5, 6, 95, 16, 1, 22, 49, 10, 4],
#  [1, 32, 2, 31, 22, 33, 23, 3, 5, 6, 95, 16, 1, 22, 49, 10, 4, 96],
#  [1, 32, 2, 31, 22, 33, 23, 3, 5, 6, 95, 16, 1, 22, 49, 10, 4, 96, 35],
#  [1, 32, 2, 31, 22, 33, 23, 3, 5, 6, 95, 16, 1, 22, 49, 10, 4, 96, 35, 7],
#  [1, 32, 2, 31, 22, 33, 23, 3, 5, 6, 95, 16, 1, 22, 49, 10, 4, 96, 35, 7, 97],
#  [1,
#   32,
#   2,
#   31,
#   22,
#   33,
#   23,
#   3,
#   5,
#   6,
#   95,
#   16,
#   1,
#   22,
#   49,
#   10,
#   4,
#   96,
#   35,
#   7,
#   97,
#   98],
#  [1,
#   32,
#   2,
#   31,
#   22,
#   33,
#   23,
#   3,
#   5,
#   6,
#   95,
#   16,
#   1,
#   22,
#   49,
#   10,
#   4,
#   96,
#   35,
#   7,
#   97,
#   98,
#   6],
#  [1,
#   32,
#   2,
#   31,
#   22,
#   33,
#   23,
#   3,
#   5,
#   6,
#   95,
#   16,
#   1,
#   22,
#   49,
#   10,
#   4,
#   96,
#   35,
#   7,
#   97,
#   98,
#   6,
#   99],
#  [1,
#   32,
#   2,
#   31,
#   22,
#   33,
#   23,
#   3,
#   5,
#   6,
#   95,
#   16,
#   1,
#   22,
#   49,
#   10,
#   4,
#   96,
#   35,
#   7,
#   97,
#   98,
#   6,
#   99,
#   100],
#  [1,
#   32,
#   2,
#   31,
#   22,
#   33,
#   23,
#   3,
#   5,
#   6,
#   95,
#   16,
#   1,
#   22,
#   49,
#   10,
#   4,
#   96,
#   35,
#   7,
#   97,
#   98,
#   6,
#   99,
#   100,
#   17],
#  [1,
#   32,
#   2,
#   31,
#   22,
#   33,
#   23,
#   3,
#   5,
#   6,
#   95,
#   16,
#   1,
#   22,
#   49,
#   10,
#   4,
#   96,
#   35,
#   7,
#   97,
#   98,
#   6,
#   99,
#   100,
#   17,
#   1],
#  [1,
#   32,
#   2,
#   31,
#   22,
#   33,
#   23,
#   3,
#   5,
#   6,
#   95,
#   16,
#   1,
#   22,
#   49,
#   10,
#   4,
#   96,
#   35,
#   7,
#   97,
#   98,
#   6,
#   99,
#   100,
#   17,
#   1,
#   101],
#  [1,
#   32,
#   2,
#   31,
#   22,
#   33,
#   23,
#   3,
#   5,
#   6,
#   95,
#   16,
#   1,
#   22,
#   49,
#   10,
#   4,
#   96,
#   35,
#   7,
#   97,
#   98,
#   6,
#   99,
#   100,
#   17,
#   1,
#   101,
#   102],
#  [36, 1],
#  [36, 1, 31],
#  [36, 1, 31, 50],
#  [36, 1, 31, 50, 25],
#  [36, 1, 31, 50, 25, 37],
#  [36, 1, 31, 50, 25, 37, 2],
#  [36, 1, 31, 50, 25, 37, 2, 103],
#  [36, 1, 31, 50, 25, 37, 2, 103, 51],
#  [36, 1, 31, 50, 25, 37, 2, 103, 51, 1],
#  [36, 1, 31, 50, 25, 37, 2, 103, 51, 1, 32],
#  [36, 1, 31, 50, 25, 37, 2, 103, 51, 1, 32, 50],
#  [36, 1, 31, 50, 25, 37, 2, 103, 51, 1, 32, 50, 25],
#  [36, 1, 31, 50, 25, 37, 2, 103, 51, 1, 32, 50, 25, 104],
#  [36, 1, 31, 50, 25, 37, 2, 103, 51, 1, 32, 50, 25, 104, 51],
#  [1, 18],
#  [1, 18, 52],
#  [1, 18, 52, 26],
#  [1, 18, 52, 26, 2],
#  [1, 18, 52, 26, 2, 27],
#  [1, 18, 52, 26, 2, 27, 9],
#  [1, 18, 52, 26, 2, 27, 9, 6],
#  [1, 18, 52, 26, 2, 27, 9, 6, 1],
#  [1, 18, 52, 26, 2, 27, 9, 6, 1, 38],
#  [1, 18, 52, 26, 2, 27, 9, 6, 1, 38, 9],
#  [1, 18, 52, 26, 2, 27, 9, 6, 1, 38, 9, 10],
#  [1, 18, 52, 26, 2, 27, 9, 6, 1, 38, 9, 10, 105],
#  [1, 18, 52, 26, 2, 27, 9, 6, 1, 38, 9, 10, 105, 106],
#  [1, 18, 52, 26, 2, 27, 9, 6, 1, 38, 9, 10, 105, 106, 1],
#  [1, 18, 52, 26, 2, 27, 9, 6, 1, 38, 9, 10, 105, 106, 1, 15],
#  [1, 18],
#  [1, 18, 9],
#  [1, 18, 9, 5],
#  [1, 18, 9, 5, 6],
#  [1, 18, 9, 5, 6, 34],
#  [1, 18, 9, 5, 6, 34, 107],
#  [1, 18, 9, 5, 6, 34, 107, 108],
#  [1, 18, 9, 5, 6, 34, 107, 108, 1],
#  [1, 18, 9, 5, 6, 34, 107, 108, 1, 109],
#  [1, 18, 9, 5, 6, 34, 107, 108, 1, 109, 6],
#  [1, 18, 9, 5, 6, 34, 107, 108, 1, 109, 6, 1],
#  [1, 18, 9, 5, 6, 34, 107, 108, 1, 109, 6, 1, 53],
#  [1, 18, 9, 5, 6, 34, 107, 108, 1, 109, 6, 1, 53, 9],
#  [1, 18, 9, 5, 6, 34, 107, 108, 1, 109, 6, 1, 53, 9, 3],
#  [1, 18, 9, 5, 6, 34, 107, 108, 1, 109, 6, 1, 53, 9, 3, 1],
#  [1, 18, 9, 5, 6, 34, 107, 108, 1, 109, 6, 1, 53, 9, 3, 1, 110],
#  [1, 18, 9, 5, 6, 34, 107, 108, 1, 109, 6, 1, 53, 9, 3, 1, 110, 12],
#  [1, 18],
#  [1, 18, 9],
#  [1, 18, 9, 6],
#  [1, 18, 9, 6, 111],
#  [1, 18, 9, 6, 111, 39],
#  [1, 18, 9, 6, 111, 39, 19],
#  [1, 18, 9, 6, 111, 39, 19, 112],
#  [1, 18, 9, 6, 111, 39, 19, 112, 54],
#  [1, 18, 9, 6, 111, 39, 19, 112, 54, 113],
#  [1, 18, 9, 6, 111, 39, 19, 112, 54, 113, 55],
#  [1, 18, 9, 6, 111, 39, 19, 112, 54, 113, 55, 2],
#  [1, 18, 9, 6, 111, 39, 19, 112, 54, 113, 55, 2, 114],
#  [1, 18, 9, 6, 111, 39, 19, 112, 54, 113, 55, 2, 114, 115],
#  [1, 18, 9, 6, 111, 39, 19, 112, 54, 113, 55, 2, 114, 115, 40],
#  [1, 18, 9, 6, 111, 39, 19, 112, 54, 113, 55, 2, 114, 115, 40, 116],
#  [1, 18, 9, 6, 111, 39, 19, 112, 54, 113, 55, 2, 114, 115, 40, 116, 117],
#  [1, 18, 9, 6, 111, 39, 19, 112, 54, 113, 55, 2, 114, 115, 40, 116, 117, 118],
#  [1,
#   18,
#   9,
#   6,
#   111,
#   39,
#   19,
#   112,
#   54,
#   113,
#   55,
#   2,
#   114,
#   115,
#   40,
#   116,
#   117,
#   118,
#   119],
#  [1,
#   18,
#   9,
#   6,
#   111,
#   39,
#   19,
#   112,
#   54,
#   113,
#   55,
#   2,
#   114,
#   115,
#   40,
#   116,
#   117,
#   118,
#   119,
#   120],
#  [1,
#   18,
#   9,
#   6,
#   111,
#   39,
#   19,
#   112,
#   54,
#   113,
#   55,
#   2,
#   114,
#   115,
#   40,
#   116,
#   117,
#   118,
#   119,
#   120,
#   56],
#  [1,
#   18,
#   9,
#   6,
#   111,
#   39,
#   19,
#   112,
#   54,
#   113,
#   55,
#   2,
#   114,
#   115,
#   40,
#   116,
#   117,
#   118,
#   119,
#   120,
#   56,
#   121],
#  [1,
#   18,
#   9,
#   6,
#   111,
#   39,
#   19,
#   112,
#   54,
#   113,
#   55,
#   2,
#   114,
#   115,
#   40,
#   116,
#   117,
#   118,
#   119,
#   120,
#   56,
#   121,
#   7],
#  [1,
#   18,
#   9,
#   6,
#   111,
#   39,
#   19,
#   112,
#   54,
#   113,
#   55,
#   2,
#   114,
#   115,
#   40,
#   116,
#   117,
#   118,
#   119,
#   120,
#   56,
#   121,
#   7,
#   57],
#  [1,
#   18,
#   9,
#   6,
#   111,
#   39,
#   19,
#   112,
#   54,
#   113,
#   55,
#   2,
#   114,
#   115,
#   40,
#   116,
#   117,
#   118,
#   119,
#   120,
#   56,
#   121,
#   7,
#   57,
#   7],
#  [1,
#   18,
#   9,
#   6,
#   111,
#   39,
#   19,
#   112,
#   54,
#   113,
#   55,
#   2,
#   114,
#   115,
#   40,
#   116,
#   117,
#   118,
#   119,
#   120,
#   56,
#   121,
#   7,
#   57,
#   7,
#   23],
#  [1,
#   18,
#   9,
#   6,
#   111,
#   39,
#   19,
#   112,
#   54,
#   113,
#   55,
#   2,
#   114,
#   115,
#   40,
#   116,
#   117,
#   118,
#   119,
#   120,
#   56,
#   121,
#   7,
#   57,
#   7,
#   23,
#   122],
#  [1,
#   18,
#   9,
#   6,
#   111,
#   39,
#   19,
#   112,
#   54,
#   113,
#   55,
#   2,
#   114,
#   115,
#   40,
#   116,
#   117,
#   118,
#   119,
#   120,
#   56,
#   121,
#   7,
#   57,
#   7,
#   23,
#   122,
#   2],
#  [1,
#   18,
#   9,
#   6,
#   111,
#   39,
#   19,
#   112,
#   54,
#   113,
#   55,
#   2,
#   114,
#   115,
#   40,
#   116,
#   117,
#   118,
#   119,
#   120,
#   56,
#   121,
#   7,
#   57,
#   7,
#   23,
#   122,
#   2,
#   123],
#  [1,
#   18,
#   9,
#   6,
#   111,
#   39,
#   19,
#   112,
#   54,
#   113,
#   55,
#   2,
#   114,
#   115,
#   40,
#   116,
#   117,
#   118,
#   119,
#   120,
#   56,
#   121,
#   7,
#   57,
#   7,
#   23,
#   122,
#   2,
#   123,
#   124],
#  [58, 1],
#  [58, 1, 18],
#  [58, 1, 18, 11],
#  [58, 1, 18, 11, 4],
#  [58, 1, 18, 11, 4, 125],
#  [58, 1, 18, 11, 4, 125, 59],
#  [58, 1, 18, 11, 4, 125, 59, 5],
#  [58, 1, 18, 11, 4, 125, 59, 5, 4],
#  [58, 1, 18, 11, 4, 125, 59, 5, 4, 39],
#  [58, 1, 18, 11, 4, 125, 59, 5, 4, 39, 19],
#  [58, 1, 18, 11, 4, 125, 59, 5, 4, 39, 19, 37],
#  [58, 1, 18, 11, 4, 125, 59, 5, 4, 39, 19, 37, 126],
#  [1, 52],
#  [1, 52, 9],
#  [1, 52, 9, 127],
#  [1, 52, 9, 127, 60],
#  [1, 52, 9, 127, 60, 61],
#  [1, 52, 9, 127, 60, 61, 128],
#  [1, 52, 9, 127, 60, 61, 128, 129],
#  [1, 52, 9, 127, 60, 61, 128, 129, 1],
#  [1, 52, 9, 127, 60, 61, 128, 129, 1, 130],
#  [1, 52, 9, 127, 60, 61, 128, 129, 1, 130, 3],
#  [1, 52, 9, 127, 60, 61, 128, 129, 1, 130, 3, 1],
#  [1, 52, 9, 127, 60, 61, 128, 129, 1, 130, 3, 1, 12],
#  [1, 52, 9, 127, 60, 61, 128, 129, 1, 130, 3, 1, 12, 24],
#  [1, 52, 9, 127, 60, 61, 128, 129, 1, 130, 3, 1, 12, 24, 1],
#  [1, 52, 9, 127, 60, 61, 128, 129, 1, 130, 3, 1, 12, 24, 1, 18],
#  [1, 52, 9, 127, 60, 61, 128, 129, 1, 130, 3, 1, 12, 24, 1, 18, 2],
#  [1, 52, 9, 127, 60, 61, 128, 129, 1, 130, 3, 1, 12, 24, 1, 18, 2, 27],
#  [1, 52, 9, 127, 60, 61, 128, 129, 1, 130, 3, 1, 12, 24, 1, 18, 2, 27, 9],
#  [1, 52, 9, 127, 60, 61, 128, 129, 1, 130, 3, 1, 12, 24, 1, 18, 2, 27, 9, 6],
#  [1,
#   52,
#   9,
#   127,
#   60,
#   61,
#   128,
#   129,
#   1,
#   130,
#   3,
#   1,
#   12,
#   24,
#   1,
#   18,
#   2,
#   27,
#   9,
#   6,
#   39],
#  [1,
#   52,
#   9,
#   127,
#   60,
#   61,
#   128,
#   129,
#   1,
#   130,
#   3,
#   1,
#   12,
#   24,
#   1,
#   18,
#   2,
#   27,
#   9,
#   6,
#   39,
#   19],
#  [1,
#   52,
#   9,
#   127,
#   60,
#   61,
#   128,
#   129,
#   1,
#   130,
#   3,
#   1,
#   12,
#   24,
#   1,
#   18,
#   2,
#   27,
#   9,
#   6,
#   39,
#   19,
#   131],
#  [1,
#   52,
#   9,
#   127,
#   60,
#   61,
#   128,
#   129,
#   1,
#   130,
#   3,
#   1,
#   12,
#   24,
#   1,
#   18,
#   2,
#   27,
#   9,
#   6,
#   39,
#   19,
#   131,
#   132],
#  [1,
#   52,
#   9,
#   127,
#   60,
#   61,
#   128,
#   129,
#   1,
#   130,
#   3,
#   1,
#   12,
#   24,
#   1,
#   18,
#   2,
#   27,
#   9,
#   6,
#   39,
#   19,
#   131,
#   132,
#   20],
#  [1,
#   52,
#   9,
#   127,
#   60,
#   61,
#   128,
#   129,
#   1,
#   130,
#   3,
#   1,
#   12,
#   24,
#   1,
#   18,
#   2,
#   27,
#   9,
#   6,
#   39,
#   19,
#   131,
#   132,
#   20,
#   2],
#  [1,
#   52,
#   9,
#   127,
#   60,
#   61,
#   128,
#   129,
#   1,
#   130,
#   3,
#   1,
#   12,
#   24,
#   1,
#   18,
#   2,
#   27,
#   9,
#   6,
#   39,
#   19,
#   131,
#   132,
#   20,
#   2,
#   56],
#  [1,
#   52,
#   9,
#   127,
#   60,
#   61,
#   128,
#   129,
#   1,
#   130,
#   3,
#   1,
#   12,
#   24,
#   1,
#   18,
#   2,
#   27,
#   9,
#   6,
#   39,
#   19,
#   131,
#   132,
#   20,
#   2,
#   56,
#   62],
#  [1, 26],
#  [1, 26, 9],
#  [1, 26, 9, 5],
#  [1, 26, 9, 5, 4],
#  [1, 26, 9, 5, 4, 133],
#  [1, 26, 9, 5, 4, 133, 48],
#  [1, 26, 9, 5, 4, 133, 48, 8],
#  [1, 26, 9, 5, 4, 133, 48, 8, 7],
#  [1, 26, 9, 5, 4, 133, 48, 8, 7, 1],
#  [1, 26, 9, 5, 4, 133, 48, 8, 7, 1, 134],
#  [1, 26, 9, 5, 4, 133, 48, 8, 7, 1, 134, 4],
#  [1, 26, 9, 5, 4, 133, 48, 8, 7, 1, 134, 4, 63],
#  [1, 26, 9, 5, 4, 133, 48, 8, 7, 1, 134, 4, 63, 135],
#  [1, 26, 9, 5, 4, 133, 48, 8, 7, 1, 134, 4, 63, 135, 8],
#  [1, 26, 9, 5, 4, 133, 48, 8, 7, 1, 134, 4, 63, 135, 8, 1],
#  [1, 26, 9, 5, 4, 133, 48, 8, 7, 1, 134, 4, 63, 135, 8, 1, 136],
#  [1, 26, 9, 5, 4, 133, 48, 8, 7, 1, 134, 4, 63, 135, 8, 1, 136, 3],
#  [1, 26, 9, 5, 4, 133, 48, 8, 7, 1, 134, 4, 63, 135, 8, 1, 136, 3, 1],
#  [1, 26, 9, 5, 4, 133, 48, 8, 7, 1, 134, 4, 63, 135, 8, 1, 136, 3, 1, 137],
#  [58, 1],
#  [58, 1, 26],
#  [58, 1, 26, 11],
#  [58, 1, 26, 11, 4],
#  [58, 1, 26, 11, 4, 1],
#  [58, 1, 26, 11, 4, 1, 138],
#  [58, 1, 26, 11, 4, 1, 138, 59],
#  [58, 1, 26, 11, 4, 1, 138, 59, 5],
#  [58, 1, 26, 11, 4, 1, 138, 59, 5, 139],
#  [58, 1, 26, 11, 4, 1, 138, 59, 5, 139, 140],
#  [58, 1, 26, 11, 4, 1, 138, 59, 5, 139, 140, 8],
#  [58, 1, 26, 11, 4, 1, 138, 59, 5, 139, 140, 8, 141],
#  [58, 1, 26, 11, 4, 1, 138, 59, 5, 139, 140, 8, 141, 23],
#  [58, 1, 26, 11, 4, 1, 138, 59, 5, 139, 140, 8, 141, 23, 142],
#  [58, 1, 26, 11, 4, 1, 138, 59, 5, 139, 140, 8, 141, 23, 142, 2],
#  [58, 1, 26, 11, 4, 1, 138, 59, 5, 139, 140, 8, 141, 23, 142, 2, 143],
#  [58, 1, 26, 11, 4, 1, 138, 59, 5, 139, 140, 8, 141, 23, 142, 2, 143, 54],
#  [16, 64],
#  [16, 64, 8],
#  [16, 64, 8, 65],
#  [16, 64, 8, 65, 37],
#  [16, 64, 8, 65, 37, 1],
#  [16, 64, 8, 65, 37, 1, 26],
#  [16, 64, 8, 65, 37, 1, 26, 11],
#  [16, 64, 8, 65, 37, 1, 26, 11, 66],
#  [16, 64, 8, 65, 37, 1, 26, 11, 66, 40],
#  [16, 64, 8, 65, 37, 1, 26, 11, 66, 40, 20],
#  [16, 64, 8, 65, 37, 1, 26, 11, 66, 40, 20, 13],
#  [16, 64, 8, 65, 37, 1, 26, 11, 66, 40, 20, 13, 10],
#  [16, 64, 8, 65, 37, 1, 26, 11, 66, 40, 20, 13, 10, 144],
#  [16, 64, 8, 65, 37, 1, 26, 11, 66, 40, 20, 13, 10, 144, 8],
#  [16, 64, 8, 65, 37, 1, 26, 11, 66, 40, 20, 13, 10, 144, 8, 1],
#  [16, 64, 8, 65, 37, 1, 26, 11, 66, 40, 20, 13, 10, 144, 8, 1, 145],
#  [16, 64, 8, 65, 37, 1, 26, 11, 66, 40, 20, 13, 10, 144, 8, 1, 145, 3],
#  [16, 64, 8, 65, 37, 1, 26, 11, 66, 40, 20, 13, 10, 144, 8, 1, 145, 3, 146],
#  [16,
#   64,
#   8,
#   65,
#   37,
#   1,
#   26,
#   11,
#   66,
#   40,
#   20,
#   13,
#   10,
#   144,
#   8,
#   1,
#   145,
#   3,
#   146,
#   147],
#  [16,
#   64,
#   8,
#   65,
#   37,
#   1,
#   26,
#   11,
#   66,
#   40,
#   20,
#   13,
#   10,
#   144,
#   8,
#   1,
#   145,
#   3,
#   146,
#   147,
#   2],
#  [16,
#   64,
#   8,
#   65,
#   37,
#   1,
#   26,
#   11,
#   66,
#   40,
#   20,
#   13,
#   10,
#   144,
#   8,
#   1,
#   145,
#   3,
#   146,
#   147,
#   2,
#   148],
#  [1, 149],
#  [1, 149, 2],
#  [1, 149, 2, 150],
#  [1, 149, 2, 150, 11],
#  [1, 149, 2, 150, 11, 3],
#  [1, 149, 2, 150, 11, 3, 1],
#  [1, 149, 2, 150, 11, 3, 1, 15],
#  [1, 149, 2, 150, 11, 3, 1, 15, 4],
#  [1, 149, 2, 150, 11, 3, 1, 15, 4, 1],
#  [1, 149, 2, 150, 11, 3, 1, 15, 4, 1, 27],
#  [1, 149, 2, 150, 11, 3, 1, 15, 4, 1, 27, 11],
#  [1, 149, 2, 150, 11, 3, 1, 15, 4, 1, 27, 11, 5],
#  [1, 149, 2, 150, 11, 3, 1, 15, 4, 1, 27, 11, 5, 4],
#  [1, 149, 2, 150, 11, 3, 1, 15, 4, 1, 27, 11, 5, 4, 1],
#  [1, 149, 2, 150, 11, 3, 1, 15, 4, 1, 27, 11, 5, 4, 1, 151],
#  [1, 149, 2, 150, 11, 3, 1, 15, 4, 1, 27, 11, 5, 4, 1, 151, 11],
#  [1, 149, 2, 150, 11, 3, 1, 15, 4, 1, 27, 11, 5, 4, 1, 151, 11, 3],
#  [1, 149, 2, 150, 11, 3, 1, 15, 4, 1, 27, 11, 5, 4, 1, 151, 11, 3, 1],
#  [1, 149, 2, 150, 11, 3, 1, 15, 4, 1, 27, 11, 5, 4, 1, 151, 11, 3, 1, 15],
#  [1, 149, 2, 150, 11, 3, 1, 15, 4, 1, 27, 11, 5, 4, 1, 151, 11, 3, 1, 15, 2],
#  [1,
#   149,
#   2,
#   150,
#   11,
#   3,
#   1,
#   15,
#   4,
#   1,
#   27,
#   11,
#   5,
#   4,
#   1,
#   151,
#   11,
#   3,
#   1,
#   15,
#   2,
#   152],
#  [1,
#   149,
#   2,
#   150,
#   11,
#   3,
#   1,
#   15,
#   4,
#   1,
#   27,
#   11,
#   5,
#   4,
#   1,
#   151,
#   11,
#   3,
#   1,
#   15,
#   2,
#   152,
#   1],
#  [1,
#   149,
#   2,
#   150,
#   11,
#   3,
#   1,
#   15,
#   4,
#   1,
#   27,
#   11,
#   5,
#   4,
#   1,
#   151,
#   11,
#   3,
#   1,
#   15,
#   2,
#   152,
#   1,
#   153],
#  [1,
#   149,
#   2,
#   150,
#   11,
#   3,
#   1,
#   15,
#   4,
#   1,
#   27,
#   11,
#   5,
#   4,
#   1,
#   151,
#   11,
#   3,
#   1,
#   15,
#   2,
#   152,
#   1,
#   153,
#   154],
#  [1,
#   149,
#   2,
#   150,
#   11,
#   3,
#   1,
#   15,
#   4,
#   1,
#   27,
#   11,
#   5,
#   4,
#   1,
#   151,
#   11,
#   3,
#   1,
#   15,
#   2,
#   152,
#   1,
#   153,
#   154,
#   3],
#  [1,
#   149,
#   2,
#   150,
#   11,
#   3,
#   1,
#   15,
#   4,
#   1,
#   27,
#   11,
#   5,
#   4,
#   1,
#   151,
#   11,
#   3,
#   1,
#   15,
#   2,
#   152,
#   1,
#   153,
#   154,
#   3,
#   1],
#  [1,
#   149,
#   2,
#   150,
#   11,
#   3,
#   1,
#   15,
#   4,
#   1,
#   27,
#   11,
#   5,
#   4,
#   1,
#   151,
#   11,
#   3,
#   1,
#   15,
#   2,
#   152,
#   1,
#   153,
#   154,
#   3,
#   1,
#   12],
#  [1, 155],
#  [1, 155, 55],
#  [1, 155, 55, 3],
#  [1, 155, 55, 3, 1],
#  [1, 155, 55, 3, 1, 27],
#  [1, 155, 55, 3, 1, 27, 11],
#  [1, 155, 55, 3, 1, 27, 11, 4],
#  [1, 155, 55, 3, 1, 27, 11, 4, 1],
#  [1, 155, 55, 3, 1, 27, 11, 4, 1, 156],
#  [1, 155, 55, 3, 1, 27, 11, 4, 1, 156, 3],
#  [1, 155, 55, 3, 1, 27, 11, 4, 1, 156, 3, 157],
#  [1, 155, 55, 3, 1, 27, 11, 4, 1, 156, 3, 157, 13],
#  [1, 155, 55, 3, 1, 27, 11, 4, 1, 156, 3, 157, 13, 1],
#  [1, 155, 55, 3, 1, 27, 11, 4, 1, 156, 3, 157, 13, 1, 158],
#  [1, 155, 55, 3, 1, 27, 11, 4, 1, 156, 3, 157, 13, 1, 158, 2],
#  [1, 155, 55, 3, 1, 27, 11, 4, 1, 156, 3, 157, 13, 1, 158, 2, 67],
#  [1, 155, 55, 3, 1, 27, 11, 4, 1, 156, 3, 157, 13, 1, 158, 2, 67, 68],
#  [1, 155, 55, 3, 1, 27, 11, 4, 1, 156, 3, 157, 13, 1, 158, 2, 67, 68, 6],
#  [1, 155, 55, 3, 1, 27, 11, 4, 1, 156, 3, 157, 13, 1, 158, 2, 67, 68, 6, 159],
#  [1,
#   155,
#   55,
#   3,
#   1,
#   27,
#   11,
#   4,
#   1,
#   156,
#   3,
#   157,
#   13,
#   1,
#   158,
#   2,
#   67,
#   68,
#   6,
#   159,
#   8],
#  [1,
#   155,
#   55,
#   3,
#   1,
#   27,
#   11,
#   4,
#   1,
#   156,
#   3,
#   157,
#   13,
#   1,
#   158,
#   2,
#   67,
#   68,
#   6,
#   159,
#   8,
#   1],
#  [1,
#   155,
#   55,
#   3,
#   1,
#   27,
#   11,
#   4,
#   1,
#   156,
#   3,
#   157,
#   13,
#   1,
#   158,
#   2,
#   67,
#   68,
#   6,
#   159,
#   8,
#   1,
#   22],
#  [1,
#   155,
#   55,
#   3,
#   1,
#   27,
#   11,
#   4,
#   1,
#   156,
#   3,
#   157,
#   13,
#   1,
#   158,
#   2,
#   67,
#   68,
#   6,
#   159,
#   8,
#   1,
#   22,
#   33],
#  [1,
#   155,
#   55,
#   3,
#   1,
#   27,
#   11,
#   4,
#   1,
#   156,
#   3,
#   157,
#   13,
#   1,
#   158,
#   2,
#   67,
#   68,
#   6,
#   159,
#   8,
#   1,
#   22,
#   33,
#   17],
#  [1,
#   155,
#   55,
#   3,
#   1,
#   27,
#   11,
#   4,
#   1,
#   156,
#   3,
#   157,
#   13,
#   1,
#   158,
#   2,
#   67,
#   68,
#   6,
#   159,
#   8,
#   1,
#   22,
#   33,
#   17,
#   1],
#  [1,
#   155,
#   55,
#   3,
#   1,
#   27,
#   11,
#   4,
#   1,
#   156,
#   3,
#   157,
#   13,
#   1,
#   158,
#   2,
#   67,
#   68,
#   6,
#   159,
#   8,
#   1,
#   22,
#   33,
#   17,
#   1,
#   41],
#  [1, 12],
#  [1, 12, 160],
#  [1, 12, 160, 60],
#  [1, 12, 160, 60, 61],
#  [1, 12, 160, 60, 61, 161],
#  [1, 12, 160, 60, 61, 161, 69],
#  [1, 12, 160, 60, 61, 161, 69, 38],
#  [1, 12, 160, 60, 61, 161, 69, 38, 162],
#  [1, 12, 160, 60, 61, 161, 69, 38, 162, 163],
#  [1, 12, 160, 60, 61, 161, 69, 38, 162, 163, 10],
#  [1, 12, 160, 60, 61, 161, 69, 38, 162, 163, 10, 70],
#  [1, 12, 160, 60, 61, 161, 69, 38, 162, 163, 10, 70, 1],
#  [1, 12, 160, 60, 61, 161, 69, 38, 162, 163, 10, 70, 1, 28],
#  [1, 12, 160, 60, 61, 161, 69, 38, 162, 163, 10, 70, 1, 28, 71],
#  [1, 12, 160, 60, 61, 161, 69, 38, 162, 163, 10, 70, 1, 28, 71, 29],
#  [1, 12, 160, 60, 61, 161, 69, 38, 162, 163, 10, 70, 1, 28, 71, 29, 2],
#  [1, 12, 160, 60, 61, 161, 69, 38, 162, 163, 10, 70, 1, 28, 71, 29, 2, 42],
#  [1, 12, 160, 60, 61, 161, 69, 38, 162, 163, 10, 70, 1, 28, 71, 29, 2, 42, 43],
#  [1, 28],
#  [1, 28, 5],
#  [1, 28, 5, 4],
#  [1, 28, 5, 4, 1],
#  [1, 28, 5, 4, 1, 72],
#  [1, 28, 5, 4, 1, 72, 164],
#  [1, 28, 5, 4, 1, 72, 164, 21],
#  [1, 28, 5, 4, 1, 72, 164, 21, 3],
#  [1, 28, 5, 4, 1, 72, 164, 21, 3, 1],
#  [1, 28, 5, 4, 1, 72, 164, 21, 3, 1, 41],
#  [1, 28, 5, 4, 1, 72, 164, 21, 3, 1, 41, 4],
#  [1, 28, 5, 4, 1, 72, 164, 21, 3, 1, 41, 4, 165],
#  [1, 28, 5, 4, 1, 72, 164, 21, 3, 1, 41, 4, 165, 166],
#  [1, 28, 5, 4, 1, 72, 164, 21, 3, 1, 41, 4, 165, 166, 69],
#  [1, 28, 5, 4, 1, 72, 164, 21, 3, 1, 41, 4, 165, 166, 69, 38],
#  [1, 28, 5, 4, 1, 72, 164, 21, 3, 1, 41, 4, 165, 166, 69, 38, 167],
#  [1, 28, 5, 4, 1, 72, 164, 21, 3, 1, 41, 4, 165, 166, 69, 38, 167, 10],
#  [1, 28, 5, 4, 1, 72, 164, 21, 3, 1, 41, 4, 165, 166, 69, 38, 167, 10, 70],
#  [1, 28, 5, 4, 1, 72, 164, 21, 3, 1, 41, 4, 165, 166, 69, 38, 167, 10, 70, 1],
#  [1,
#   28,
#   5,
#   4,
#   1,
#   72,
#   164,
#   21,
#   3,
#   1,
#   41,
#   4,
#   165,
#   166,
#   69,
#   38,
#   167,
#   10,
#   70,
#   1,
#   168],
#  [1,
#   28,
#   5,
#   4,
#   1,
#   72,
#   164,
#   21,
#   3,
#   1,
#   41,
#   4,
#   165,
#   166,
#   69,
#   38,
#   167,
#   10,
#   70,
#   1,
#   168,
#   169],
#  [1,
#   28,
#   5,
#   4,
#   1,
#   72,
#   164,
#   21,
#   3,
#   1,
#   41,
#   4,
#   165,
#   166,
#   69,
#   38,
#   167,
#   10,
#   70,
#   1,
#   168,
#   169,
#   14],
#  [1,
#   28,
#   5,
#   4,
#   1,
#   72,
#   164,
#   21,
#   3,
#   1,
#   41,
#   4,
#   165,
#   166,
#   69,
#   38,
#   167,
#   10,
#   70,
#   1,
#   168,
#   169,
#   14,
#   2],
#  [1,
#   28,
#   5,
#   4,
#   1,
#   72,
#   164,
#   21,
#   3,
#   1,
#   41,
#   4,
#   165,
#   166,
#   69,
#   38,
#   167,
#   10,
#   70,
#   1,
#   168,
#   169,
#   14,
#   2,
#   73],
#  [1, 73],
#  [1, 73, 5],
#  [1, 73, 5, 4],
#  [1, 73, 5, 4, 1],
#  [1, 73, 5, 4, 1, 53],
#  [1, 73, 5, 4, 1, 53, 21],
#  [1, 73, 5, 4, 1, 53, 21, 3],
#  [1, 73, 5, 4, 1, 53, 21, 3, 1],
#  [1, 73, 5, 4, 1, 53, 21, 3, 1, 28],
#  [1, 73, 5, 4, 1, 53, 21, 3, 1, 28, 170],
#  [1, 73, 5, 4, 1, 53, 21, 3, 1, 28, 170, 7],
#  [1, 73, 5, 4, 1, 53, 21, 3, 1, 28, 170, 7, 30],
#  [1, 73, 5, 4, 1, 53, 21, 3, 1, 28, 170, 7, 30, 171],
#  [1, 73, 5, 4, 1, 53, 21, 3, 1, 28, 170, 7, 30, 171, 172],
#  [1, 73, 5, 4, 1, 53, 21, 3, 1, 28, 170, 7, 30, 171, 172, 19],
#  [1, 73, 5, 4, 1, 53, 21, 3, 1, 28, 170, 7, 30, 171, 172, 19, 44],
#  [1, 73, 5, 4, 1, 53, 21, 3, 1, 28, 170, 7, 30, 171, 172, 19, 44, 20],
#  [1, 73, 5, 4, 1, 53, 21, 3, 1, 28, 170, 7, 30, 171, 172, 19, 44, 20, 13],
#  [1, 73, 5, 4, 1, 53, 21, 3, 1, 28, 170, 7, 30, 171, 172, 19, 44, 20, 13, 10],
#  [1,
#   73,
#   5,
#   4,
#   1,
#   53,
#   21,
#   3,
#   1,
#   28,
#   170,
#   7,
#   30,
#   171,
#   172,
#   19,
#   44,
#   20,
#   13,
#   10,
#   173],
#  [1,
#   73,
#   5,
#   4,
#   1,
#   53,
#   21,
#   3,
#   1,
#   28,
#   170,
#   7,
#   30,
#   171,
#   172,
#   19,
#   44,
#   20,
#   13,
#   10,
#   173,
#   1],
#  [1,
#   73,
#   5,
#   4,
#   1,
#   53,
#   21,
#   3,
#   1,
#   28,
#   170,
#   7,
#   30,
#   171,
#   172,
#   19,
#   44,
#   20,
#   13,
#   10,
#   173,
#   1,
#   49],
#  [1,
#   73,
#   5,
#   4,
#   1,
#   53,
#   21,
#   3,
#   1,
#   28,
#   170,
#   7,
#   30,
#   171,
#   172,
#   19,
#   44,
#   20,
#   13,
#   10,
#   173,
#   1,
#   49,
#   2],
#  [1,
#   73,
#   5,
#   4,
#   1,
#   53,
#   21,
#   3,
#   1,
#   28,
#   170,
#   7,
#   30,
#   171,
#   172,
#   19,
#   44,
#   20,
#   13,
#   10,
#   173,
#   1,
#   49,
#   2,
#   174],
#  [1,
#   73,
#   5,
#   4,
#   1,
#   53,
#   21,
#   3,
#   1,
#   28,
#   170,
#   7,
#   30,
#   171,
#   172,
#   19,
#   44,
#   20,
#   13,
#   10,
#   173,
#   1,
#   49,
#   2,
#   174,
#   175],
#  [1,
#   73,
#   5,
#   4,
#   1,
#   53,
#   21,
#   3,
#   1,
#   28,
#   170,
#   7,
#   30,
#   171,
#   172,
#   19,
#   44,
#   20,
#   13,
#   10,
#   173,
#   1,
#   49,
#   2,
#   174,
#   175,
#   176],
#  [1,
#   73,
#   5,
#   4,
#   1,
#   53,
#   21,
#   3,
#   1,
#   28,
#   170,
#   7,
#   30,
#   171,
#   172,
#   19,
#   44,
#   20,
#   13,
#   10,
#   173,
#   1,
#   49,
#   2,
#   174,
#   175,
#   176,
#   8],
#  [1,
#   73,
#   5,
#   4,
#   1,
#   53,
#   21,
#   3,
#   1,
#   28,
#   170,
#   7,
#   30,
#   171,
#   172,
#   19,
#   44,
#   20,
#   13,
#   10,
#   173,
#   1,
#   49,
#   2,
#   174,
#   175,
#   176,
#   8,
#   1],
#  [1,
#   73,
#   5,
#   4,
#   1,
#   53,
#   21,
#   3,
#   1,
#   28,
#   170,
#   7,
#   30,
#   171,
#   172,
#   19,
#   44,
#   20,
#   13,
#   10,
#   173,
#   1,
#   49,
#   2,
#   174,
#   175,
#   176,
#   8,
#   1,
#   15],
#  [1,
#   73,
#   5,
#   4,
#   1,
#   53,
#   21,
#   3,
#   1,
#   28,
#   170,
#   7,
#   30,
#   171,
#   172,
#   19,
#   44,
#   20,
#   13,
#   10,
#   173,
#   1,
#   49,
#   2,
#   174,
#   175,
#   176,
#   8,
#   1,
#   15,
#   19],
#  [1,
#   73,
#   5,
#   4,
#   1,
#   53,
#   21,
#   3,
#   1,
#   28,
#   170,
#   7,
#   30,
#   171,
#   172,
#   19,
#   44,
#   20,
#   13,
#   10,
#   173,
#   1,
#   49,
#   2,
#   174,
#   175,
#   176,
#   8,
#   1,
#   15,
#   19,
#   65],
#  [1, 14],
#  [1, 14, 66],
#  [1, 14, 66, 40],
#  [1, 14, 66, 40, 177],
#  [1, 14, 66, 40, 177, 20],
#  [1, 14, 66, 40, 177, 20, 13],
#  [1, 14, 66, 40, 177, 20, 13, 178],
#  [1, 14, 66, 40, 177, 20, 13, 178, 44],
#  [1, 14, 66, 40, 177, 20, 13, 178, 44, 3],
#  [1, 14, 66, 40, 177, 20, 13, 178, 44, 3, 1],
#  [1, 14, 66, 40, 177, 20, 13, 178, 44, 3, 1, 13],
#  [1, 14, 66, 40, 177, 20, 13, 178, 44, 3, 1, 13, 74],
#  [1, 14, 66, 40, 177, 20, 13, 178, 44, 3, 1, 13, 74, 17],
#  [1, 14, 66, 40, 177, 20, 13, 178, 44, 3, 1, 13, 74, 17, 1],
#  [1, 14, 66, 40, 177, 20, 13, 178, 44, 3, 1, 13, 74, 17, 1, 14],
#  [1, 14, 66, 40, 177, 20, 13, 178, 44, 3, 1, 13, 74, 17, 1, 14, 4],
#  [1, 14, 66, 40, 177, 20, 13, 178, 44, 3, 1, 13, 74, 17, 1, 14, 4, 179],
#  [1, 14, 66, 40, 177, 20, 13, 178, 44, 3, 1, 13, 74, 17, 1, 14, 4, 179, 75],
#  [1, 14, 66, 40, 177, 20, 13, 178, 44, 3, 1, 13, 74, 17, 1, 14, 4, 179, 75, 1],
#  [1,
#   14,
#   66,
#   40,
#   177,
#   20,
#   13,
#   178,
#   44,
#   3,
#   1,
#   13,
#   74,
#   17,
#   1,
#   14,
#   4,
#   179,
#   75,
#   1,
#   76],
#  [1,
#   14,
#   66,
#   40,
#   177,
#   20,
#   13,
#   178,
#   44,
#   3,
#   1,
#   13,
#   74,
#   17,
#   1,
#   14,
#   4,
#   179,
#   75,
#   1,
#   76,
#   180],
#  [1,
#   14,
#   66,
#   40,
#   177,
#   20,
#   13,
#   178,
#   44,
#   3,
#   1,
#   13,
#   74,
#   17,
#   1,
#   14,
#   4,
#   179,
#   75,
#   1,
#   76,
#   180,
#   181],
#  [1,
#   14,
#   66,
#   40,
#   177,
#   20,
#   13,
#   178,
#   44,
#   3,
#   1,
#   13,
#   74,
#   17,
#   1,
#   14,
#   4,
#   179,
#   75,
#   1,
#   76,
#   180,
#   181,
#   182],
#  [7, 30],
#  [7, 30, 183],
#  [7, 30, 183, 1],
#  [7, 30, 183, 1, 14],
#  [7, 30, 183, 1, 14, 184],
#  [7, 30, 183, 1, 14, 184, 185],
#  [7, 30, 183, 1, 14, 184, 185, 186],
#  [7, 30, 183, 1, 14, 184, 185, 186, 187],
#  [7, 30, 183, 1, 14, 184, 185, 186, 187, 188],
#  [7, 30, 183, 1, 14, 184, 185, 186, 187, 188, 2],
#  [7, 30, 183, 1, 14, 184, 185, 186, 187, 188, 2, 189],
#  [7, 30, 183, 1, 14, 184, 185, 186, 187, 188, 2, 189, 190],
#  [7, 30, 183, 1, 14, 184, 185, 186, 187, 188, 2, 189, 190, 16],
#  [7, 30, 183, 1, 14, 184, 185, 186, 187, 188, 2, 189, 190, 16, 64],
#  [7, 30, 183, 1, 14, 184, 185, 186, 187, 188, 2, 189, 190, 16, 64, 8],
#  [7, 30, 183, 1, 14, 184, 185, 186, 187, 188, 2, 189, 190, 16, 64, 8, 191],
#  [7,
#   30,
#   183,
#   1,
#   14,
#   184,
#   185,
#   186,
#   187,
#   188,
#   2,
#   189,
#   190,
#   16,
#   64,
#   8,
#   191,
#   192],
#  [7,
#   30,
#   183,
#   1,
#   14,
#   184,
#   185,
#   186,
#   187,
#   188,
#   2,
#   189,
#   190,
#   16,
#   64,
#   8,
#   191,
#   192,
#   193],
#  [7,
#   30,
#   183,
#   1,
#   14,
#   184,
#   185,
#   186,
#   187,
#   188,
#   2,
#   189,
#   190,
#   16,
#   64,
#   8,
#   191,
#   192,
#   193,
#   194],
#  [7,
#   30,
#   183,
#   1,
#   14,
#   184,
#   185,
#   186,
#   187,
#   188,
#   2,
#   189,
#   190,
#   16,
#   64,
#   8,
#   191,
#   192,
#   193,
#   194,
#   195],
#  [196, 1],
#  [196, 1, 197],
#  [196, 1, 197, 3],
#  [196, 1, 197, 3, 1],
#  [196, 1, 197, 3, 1, 198],
#  [196, 1, 197, 3, 1, 198, 199],
#  [196, 1, 197, 3, 1, 198, 199, 5],
#  [196, 1, 197, 3, 1, 198, 199, 5, 200],
#  [196, 1, 197, 3, 1, 198, 199, 5, 200, 75],
#  [196, 1, 197, 3, 1, 198, 199, 5, 200, 75, 30],
#  [196, 1, 197, 3, 1, 198, 199, 5, 200, 75, 30, 201],
#  [196, 1, 197, 3, 1, 198, 199, 5, 200, 75, 30, 201, 202],
#  [196, 1, 197, 3, 1, 198, 199, 5, 200, 75, 30, 201, 202, 3],
#  [196, 1, 197, 3, 1, 198, 199, 5, 200, 75, 30, 201, 202, 3, 1],
#  [196, 1, 197, 3, 1, 198, 199, 5, 200, 75, 30, 201, 202, 3, 1, 14],
#  [196, 1, 197, 3, 1, 198, 199, 5, 200, 75, 30, 201, 202, 3, 1, 14, 4],
#  [196, 1, 197, 3, 1, 198, 199, 5, 200, 75, 30, 201, 202, 3, 1, 14, 4, 203],
#  [196, 1, 197, 3, 1, 198, 199, 5, 200, 75, 30, 201, 202, 3, 1, 14, 4, 203, 17],
#  [196,
#   1,
#   197,
#   3,
#   1,
#   198,
#   199,
#   5,
#   200,
#   75,
#   30,
#   201,
#   202,
#   3,
#   1,
#   14,
#   4,
#   203,
#   17,
#   1],
#  [196,
#   1,
#   197,
#   3,
#   1,
#   198,
#   199,
#   5,
#   200,
#   75,
#   30,
#   201,
#   202,
#   3,
#   1,
#   14,
#   4,
#   203,
#   17,
#   1,
#   14],
#  [1, 71],
#  [1, 71, 5],
#  [1, 71, 5, 204],
#  [1, 71, 5, 204, 1],
#  [1, 71, 5, 204, 1, 28],
#  [1, 71, 5, 204, 1, 28, 8],
#  [1, 71, 5, 204, 1, 28, 8, 1],
#  [1, 71, 5, 204, 1, 28, 8, 1, 29],
#  [1, 71, 5, 204, 1, 28, 8, 1, 29, 25],
#  [1, 71, 5, 204, 1, 28, 8, 1, 29, 25, 205],
#  [1, 71, 5, 204, 1, 28, 8, 1, 29, 25, 205, 206],
#  [1, 71, 5, 204, 1, 28, 8, 1, 29, 25, 205, 206, 36],
#  [1, 71, 5, 204, 1, 28, 8, 1, 29, 25, 205, 206, 36, 1],
#  [1, 71, 5, 204, 1, 28, 8, 1, 29, 25, 205, 206, 36, 1, 29],
#  [1, 71, 5, 204, 1, 28, 8, 1, 29, 25, 205, 206, 36, 1, 29, 4],
#  [1, 71, 5, 204, 1, 28, 8, 1, 29, 25, 205, 206, 36, 1, 29, 4, 207],
#  [1, 71, 5, 204, 1, 28, 8, 1, 29, 25, 205, 206, 36, 1, 29, 4, 207, 16],
#  [1, 71, 5, 204, 1, 28, 8, 1, 29, 25, 205, 206, 36, 1, 29, 4, 207, 16, 1],
#  [1, 71, 5, 204, 1, 28, 8, 1, 29, 25, 205, 206, 36, 1, 29, 4, 207, 16, 1, 208],
#  [1,
#   71,
#   5,
#   204,
#   1,
#   28,
#   8,
#   1,
#   29,
#   25,
#   205,
#   206,
#   36,
#   1,
#   29,
#   4,
#   207,
#   16,
#   1,
#   208,
#   3],
#  [1,
#   71,
#   5,
#   204,
#   1,
#   28,
#   8,
#   1,
#   29,
#   25,
#   205,
#   206,
#   36,
#   1,
#   29,
#   4,
#   207,
#   16,
#   1,
#   208,
#   3,
#   209],
#  [1,
#   71,
#   5,
#   204,
#   1,
#   28,
#   8,
#   1,
#   29,
#   25,
#   205,
#   206,
#   36,
#   1,
#   29,
#   4,
#   207,
#   16,
#   1,
#   208,
#   3,
#   209,
#   2],
#  [1,
#   71,
#   5,
#   204,
#   1,
#   28,
#   8,
#   1,
#   29,
#   25,
#   205,
#   206,
#   36,
#   1,
#   29,
#   4,
#   207,
#   16,
#   1,
#   208,
#   3,
#   209,
#   2,
#   77],
#  [1,
#   71,
#   5,
#   204,
#   1,
#   28,
#   8,
#   1,
#   29,
#   25,
#   205,
#   206,
#   36,
#   1,
#   29,
#   4,
#   207,
#   16,
#   1,
#   208,
#   3,
#   209,
#   2,
#   77,
#   210],
#  [1,
#   71,
#   5,
#   204,
#   1,
#   28,
#   8,
#   1,
#   29,
#   25,
#   205,
#   206,
#   36,
#   1,
#   29,
#   4,
#   207,
#   16,
#   1,
#   208,
#   3,
#   209,
#   2,
#   77,
#   210,
#   211],
#  [1,
#   71,
#   5,
#   204,
#   1,
#   28,
#   8,
#   1,
#   29,
#   25,
#   205,
#   206,
#   36,
#   1,
#   29,
#   4,
#   207,
#   16,
#   1,
#   208,
#   3,
#   209,
#   2,
#   77,
#   210,
#   211,
#   2],
#  [1,
#   71,
#   5,
#   204,
#   1,
#   28,
#   8,
#   1,
#   29,
#   25,
#   205,
#   206,
#   36,
#   1,
#   29,
#   4,
#   207,
#   16,
#   1,
#   208,
#   3,
#   209,
#   2,
#   77,
#   210,
#   211,
#   2,
#   212],
#  [1,
#   71,
#   5,
#   204,
#   1,
#   28,
#   8,
#   1,
#   29,
#   25,
#   205,
#   206,
#   36,
#   1,
#   29,
#   4,
#   207,
#   16,
#   1,
#   208,
#   3,
#   209,
#   2,
#   77,
#   210,
#   211,
#   2,
#   212,
#   7],
#  [1,
#   71,
#   5,
#   204,
#   1,
#   28,
#   8,
#   1,
#   29,
#   25,
#   205,
#   206,
#   36,
#   1,
#   29,
#   4,
#   207,
#   16,
#   1,
#   208,
#   3,
#   209,
#   2,
#   77,
#   210,
#   211,
#   2,
#   212,
#   7,
#   57],
#  [1,
#   71,
#   5,
#   204,
#   1,
#   28,
#   8,
#   1,
#   29,
#   25,
#   205,
#   206,
#   36,
#   1,
#   29,
#   4,
#   207,
#   16,
#   1,
#   208,
#   3,
#   209,
#   2,
#   77,
#   210,
#   211,
#   2,
#   212,
#   7,
#   57,
#   7],
#  [1,
#   71,
#   5,
#   204,
#   1,
#   28,
#   8,
#   1,
#   29,
#   25,
#   205,
#   206,
#   36,
#   1,
#   29,
#   4,
#   207,
#   16,
#   1,
#   208,
#   3,
#   209,
#   2,
#   77,
#   210,
#   211,
#   2,
#   212,
#   7,
#   57,
#   7,
#   44],
#  [1,
#   71,
#   5,
#   204,
#   1,
#   28,
#   8,
#   1,
#   29,
#   25,
#   205,
#   206,
#   36,
#   1,
#   29,
#   4,
#   207,
#   16,
#   1,
#   208,
#   3,
#   209,
#   2,
#   77,
#   210,
#   211,
#   2,
#   212,
#   7,
#   57,
#   7,
#   44,
#   20],
#  [1,
#   71,
#   5,
#   204,
#   1,
#   28,
#   8,
#   1,
#   29,
#   25,
#   205,
#   206,
#   36,
#   1,
#   29,
#   4,
#   207,
#   16,
#   1,
#   208,
#   3,
#   209,
#   2,
#   77,
#   210,
#   211,
#   2,
#   212,
#   7,
#   57,
#   7,
#   44,
#   20,
#   13],
#  [1,
#   71,
#   5,
#   204,
#   1,
#   28,
#   8,
#   1,
#   29,
#   25,
#   205,
#   206,
#   36,
#   1,
#   29,
#   4,
#   207,
#   16,
#   1,
#   208,
#   3,
#   209,
#   2,
#   77,
#   210,
#   211,
#   2,
#   212,
#   7,
#   57,
#   7,
#   44,
#   20,
#   13,
#   74],
#  [1,
#   71,
#   5,
#   204,
#   1,
#   28,
#   8,
#   1,
#   29,
#   25,
#   205,
#   206,
#   36,
#   1,
#   29,
#   4,
#   207,
#   16,
#   1,
#   208,
#   3,
#   209,
#   2,
#   77,
#   210,
#   211,
#   2,
#   212,
#   7,
#   57,
#   7,
#   44,
#   20,
#   13,
#   74,
#   17],
#  [1,
#   71,
#   5,
#   204,
#   1,
#   28,
#   8,
#   1,
#   29,
#   25,
#   205,
#   206,
#   36,
#   1,
#   29,
#   4,
#   207,
#   16,
#   1,
#   208,
#   3,
#   209,
#   2,
#   77,
#   210,
#   211,
#   2,
#   212,
#   7,
#   57,
#   7,
#   44,
#   20,
#   13,
#   74,
#   17,
#   1],
#  [1,
#   71,
#   5,
#   204,
#   1,
#   28,
#   8,
#   1,
#   29,
#   25,
#   205,
#   206,
#   36,
#   1,
#   29,
#   4,
#   207,
#   16,
#   1,
#   208,
#   3,
#   209,
#   2,
#   77,
#   210,
#   211,
#   2,
#   212,
#   7,
#   57,
#   7,
#   44,
#   20,
#   13,
#   74,
#   17,
#   1,
#   77],
#  [1,
#   71,
#   5,
#   204,
#   1,
#   28,
#   8,
#   1,
#   29,
#   25,
#   205,
#   206,
#   36,
#   1,
#   29,
#   4,
#   207,
#   16,
#   1,
#   208,
#   3,
#   209,
#   2,
#   77,
#   210,
#   211,
#   2,
#   212,
#   7,
#   57,
#   7,
#   44,
#   20,
#   13,
#   74,
#   17,
#   1,
#   77,
#   213],
#  [1, 42],
#  [1, 42, 43],
#  [1, 42, 43, 5],
#  [1, 42, 43, 5, 4],
#  [1, 42, 43, 5, 4, 63],
#  [1, 42, 43, 5, 4, 63, 24],
#  [1, 42, 43, 5, 4, 63, 24, 1],
#  [1, 42, 43, 5, 4, 63, 24, 1, 29],
#  [1, 42, 43, 5, 4, 63, 24, 1, 29, 2],
#  [1, 42, 43, 5, 4, 63, 24, 1, 29, 2, 1],
#  [1, 42, 43, 5, 4, 63, 24, 1, 29, 2, 1, 67],
#  [1, 42, 43, 5, 4, 63, 24, 1, 29, 2, 1, 67, 68],
#  [1, 42, 43, 5, 4, 63, 24, 1, 29, 2, 1, 67, 68, 2],
#  [1, 42, 43, 5, 4, 63, 24, 1, 29, 2, 1, 67, 68, 2, 4],
#  [1, 42, 43, 5, 4, 63, 24, 1, 29, 2, 1, 67, 68, 2, 4, 214],
#  [1, 42, 43, 5, 4, 63, 24, 1, 29, 2, 1, 67, 68, 2, 4, 214, 1],
#  [1, 42, 43, 5, 4, 63, 24, 1, 29, 2, 1, 67, 68, 2, 4, 214, 1, 72],
#  [1, 42, 43, 5, 4, 63, 24, 1, 29, 2, 1, 67, 68, 2, 4, 214, 1, 72, 215],
#  [1, 42, 43, 5, 4, 63, 24, 1, 29, 2, 1, 67, 68, 2, 4, 214, 1, 72, 215, 21],
#  [1, 42, 43, 5, 4, 63, 24, 1, 29, 2, 1, 67, 68, 2, 4, 214, 1, 72, 215, 21, 3],
#  [1,
#   42,
#   43,
#   5,
#   4,
#   63,
#   24,
#   1,
#   29,
#   2,
#   1,
#   67,
#   68,
#   2,
#   4,
#   214,
#   1,
#   72,
#   215,
#   21,
#   3,
#   1],
#  [1,
#   42,
#   43,
#   5,
#   4,
#   63,
#   24,
#   1,
#   29,
#   2,
#   1,
#   67,
#   68,
#   2,
#   4,
#   214,
#   1,
#   72,
#   215,
#   21,
#   3,
#   1,
#   41],
#  [1,
#   42,
#   43,
#   5,
#   4,
#   63,
#   24,
#   1,
#   29,
#   2,
#   1,
#   67,
#   68,
#   2,
#   4,
#   214,
#   1,
#   72,
#   215,
#   21,
#   3,
#   1,
#   41,
#   25],
#  [1,
#   42,
#   43,
#   5,
#   4,
#   63,
#   24,
#   1,
#   29,
#   2,
#   1,
#   67,
#   68,
#   2,
#   4,
#   214,
#   1,
#   72,
#   215,
#   21,
#   3,
#   1,
#   41,
#   25,
#   76],
#  [1,
#   42,
#   43,
#   5,
#   4,
#   63,
#   24,
#   1,
#   29,
#   2,
#   1,
#   67,
#   68,
#   2,
#   4,
#   214,
#   1,
#   72,
#   215,
#   21,
#   3,
#   1,
#   41,
#   25,
#   76,
#   62],
#  [1,
#   42,
#   43,
#   5,
#   4,
#   63,
#   24,
#   1,
#   29,
#   2,
#   1,
#   67,
#   68,
#   2,
#   4,
#   214,
#   1,
#   72,
#   215,
#   21,
#   3,
#   1,
#   41,
#   25,
#   76,
#   62,
#   216],
#  [1,
#   42,
#   43,
#   5,
#   4,
#   63,
#   24,
#   1,
#   29,
#   2,
#   1,
#   67,
#   68,
#   2,
#   4,
#   214,
#   1,
#   72,
#   215,
#   21,
#   3,
#   1,
#   41,
#   25,
#   76,
#   62,
#   216,
#   7],
#  [1,
#   42,
#   43,
#   5,
#   4,
#   63,
#   24,
#   1,
#   29,
#   2,
#   1,
#   67,
#   68,
#   2,
#   4,
#   214,
#   1,
#   72,
#   215,
#   21,
#   3,
#   1,
#   41,
#   25,
#   76,
#   62,
#   216,
#   7,
#   217],
#  [1,
#   42,
#   43,
#   5,
#   4,
#   63,
#   24,
#   1,
#   29,
#   2,
#   1,
#   67,
#   68,
#   2,
#   4,
#   214,
#   1,
#   72,
#   215,
#   21,
#   3,
#   1,
#   41,
#   25,
#   76,
#   62,
#   216,
#   7,
#   217,
#   218],
#  [1,
#   42,
#   43,
#   5,
#   4,
#   63,
#   24,
#   1,
#   29,
#   2,
#   1,
#   67,
#   68,
#   2,
#   4,
#   214,
#   1,
#   72,
#   215,
#   21,
#   3,
#   1,
#   41,
#   25,
#   76,
#   62,
#   216,
#   7,
#   217,
#   218,
#   219],
#  [1,
#   42,
#   43,
#   5,
#   4,
#   63,
#   24,
#   1,
#   29,
#   2,
#   1,
#   67,
#   68,
#   2,
#   4,
#   214,
#   1,
#   72,
#   215,
#   21,
#   3,
#   1,
#   41,
#   25,
#   76,
#   62,
#   216,
#   7,
#   217,
#   218,
#   219,
#   220],
#  [1,
#   42,
#   43,
#   5,
#   4,
#   63,
#   24,
#   1,
#   29,
#   2,
#   1,
#   67,
#   68,
#   2,
#   4,
#   214,
#   1,
#   72,
#   215,
#   21,
#   3,
#   1,
#   41,
#   25,
#   76,
#   62,
#   216,
#   7,
#   217,
#   218,
#   219,
#   220,
#   221],
#  [1,
#   42,
#   43,
#   5,
#   4,
#   63,
#   24,
#   1,
#   29,
#   2,
#   1,
#   67,
#   68,
#   2,
#   4,
#   214,
#   1,
#   72,
#   215,
#   21,
#   3,
#   1,
#   41,
#   25,
#   76,
#   62,
#   216,
#   7,
#   217,
#   218,
#   219,
#   220,
#   221,
#   2],
#  [1,
#   42,
#   43,
#   5,
#   4,
#   63,
#   24,
#   1,
#   29,
#   2,
#   1,
#   67,
#   68,
#   2,
#   4,
#   214,
#   1,
#   72,
#   215,
#   21,
#   3,
#   1,
#   41,
#   25,
#   76,
#   62,
#   216,
#   7,
#   217,
#   218,
#   219,
#   220,
#   221,
#   2,
#   222],
#  [223, 12],
#  [223, 12, 224],
#  [223, 12, 224, 3],
#  [223, 12, 224, 3, 225],
#  [223, 12, 224, 3, 225, 16],
#  [223, 12, 224, 3, 225, 16, 30],
#  [223, 12, 224, 3, 225, 16, 30, 226],
#  [223, 12, 224, 3, 225, 16, 30, 226, 227],
#  [223, 12, 224, 3, 225, 16, 30, 226, 227, 4],
#  [223, 12, 224, 3, 225, 16, 30, 226, 227, 4, 228],
#  [223, 12, 224, 3, 225, 16, 30, 226, 227, 4, 228, 229],
#  [223, 12, 224, 3, 225, 16, 30, 226, 227, 4, 228, 229, 230],
#  [223, 12, 224, 3, 225, 16, 30, 226, 227, 4, 228, 229, 230, 4],
#  [223, 12, 224, 3, 225, 16, 30, 226, 227, 4, 228, 229, 230, 4, 231],
#  [223, 12, 224, 3, 225, 16, 30, 226, 227, 4, 228, 229, 230, 4, 231, 232],
#  [223, 12, 224, 3, 225, 16, 30, 226, 227, 4, 228, 229, 230, 4, 231, 232, 3],
#  [223, 12, 224, 3, 225, 16, 30, 226, 227, 4, 228, 229, 230, 4, 231, 232, 3, 1],
#  [223,
#   12,
#   224,
#   3,
#   225,
#   16,
#   30,
#   226,
#   227,
#   4,
#   228,
#   229,
#   230,
#   4,
#   231,
#   232,
#   3,
#   1,
#   42],
#  [223,
#   12,
#   224,
#   3,
#   225,
#   16,
#   30,
#   226,
#   227,
#   4,
#   228,
#   229,
#   230,
#   4,
#   231,
#   232,
#   3,
#   1,
#   42,
#   43]]

# %%
max_len = max([len(x) for x in input_sequences])

# %%
from tensorflow.keras.preprocessing.sequence import pad_sequences
padded_input_sequences = pad_sequences(input_sequences, maxlen = max_len, padding='pre')

# %%
padded_input_sequences
# Out:
# array([[  0,   0,   0, ...,   0,   1,  78],
#        [  0,   0,   0, ...,   1,  78,  21],
#        [  0,   0,   0, ...,  78,  21,   3],
#        ...,
#        [  0,   0,   0, ..., 232,   3,   1],
#        [  0,   0,   0, ...,   3,   1,  42],
#        [  0,   0,   0, ...,   1,  42,  43]])

# %%
X = padded_input_sequences[:,:-1]

# %%
y = padded_input_sequences[:,-1]

# %%
X.shape
# Out:
# (538, 38)

# %%
y.shape
# Out:
# (538,)

# %%
from tensorflow.keras.utils import to_categorical
y = to_categorical(y,num_classes=233)

# %%
y.shape
# Out:
# (538, 233)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, LSTM, Dense

# %%
model = Sequential()
model.add(Embedding(233, 100, input_length=38))
model.add(LSTM(150))
model.add(Dense(233, activation='softmax'))
# Out:
# c:\Users\aksha\anaconda2\envs\aipytorch\Lib\site-packages\keras\src\layers\core\embedding.py:90: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(

# %%
model.compile(loss='categorical_crossentropy', optimizer='adam',metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding (Embedding)           │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm (LSTM)                     │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ ?                      │   0 (unbuilt) │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 0 (0.00 B)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
model.fit(X,y,epochs=100)
# Out:
# Epoch 1/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 5s 32ms/step - accuracy: 0.0606 - loss: 5.4262
# Epoch 2/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - accuracy: 0.1083 - loss: 4.9170
# Epoch 3/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - accuracy: 0.1265 - loss: 4.7100
# Epoch 4/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - accuracy: 0.1190 - loss: 4.7605
# Epoch 5/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - accuracy: 0.1248 - loss: 4.7261
# Epoch 6/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - accuracy: 0.1004 - loss: 4.6860
# Epoch 7/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - accuracy: 0.1037 - loss: 4.6551
# Epoch 8/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - accuracy: 0.1191 - loss: 4.5297
# Epoch 9/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - accuracy: 0.1190 - loss: 4.3579
# Epoch 10/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - accuracy: 0.1637 - loss: 4.2228
# Epoch 11/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - accuracy: 0.1650 - loss: 4.0256
# Epoch 12/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - accuracy: 0.1665 - loss: 3.9449
# Epoch 13/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - accuracy: 0.2363 - loss: 3.7053
# Epoch 14/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - accuracy: 0.2140 - loss: 3.7281
# Epoch 15/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - accuracy: 0.2326 - loss: 3.5587
# Epoch 16/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - accuracy: 0.2615 - loss: 3.4305
# Epoch 17/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - accuracy: 0.2608 - loss: 3.2364
# Epoch 18/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - accuracy: 0.2914 - loss: 3.1003
# Epoch 19/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - accuracy: 0.3496 - loss: 2.8640
# Epoch 20/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - accuracy: 0.3975 - loss: 2.7083
# Epoch 21/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - accuracy: 0.3852 - loss: 2.6414
# Epoch 22/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - accuracy: 0.4474 - loss: 2.4867
# Epoch 23/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - accuracy: 0.4666 - loss: 2.3812
# Epoch 24/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - accuracy: 0.5054 - loss: 2.1930
# Epoch 25/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - accuracy: 0.5904 - loss: 2.0024
# Epoch 26/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - accuracy: 0.6217 - loss: 1.9778
# Epoch 27/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - accuracy: 0.6551 - loss: 1.8599
# Epoch 28/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - accuracy: 0.6895 - loss: 1.6993
# Epoch 29/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - accuracy: 0.6782 - loss: 1.7144
# Epoch 30/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - accuracy: 0.7542 - loss: 1.5121
# Epoch 31/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - accuracy: 0.7712 - loss: 1.4603
# Epoch 32/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - accuracy: 0.8106 - loss: 1.3366
# Epoch 33/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - accuracy: 0.8164 - loss: 1.2292
# Epoch 34/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - accuracy: 0.8353 - loss: 1.2188
# Epoch 35/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - accuracy: 0.8518 - loss: 1.1486
# Epoch 36/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - accuracy: 0.8708 - loss: 1.0730
# Epoch 37/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - accuracy: 0.8668 - loss: 0.9922
# Epoch 38/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - accuracy: 0.8567 - loss: 0.9983
# Epoch 39/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - accuracy: 0.9011 - loss: 0.9053
# Epoch 40/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - accuracy: 0.8959 - loss: 0.8589
# Epoch 41/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - accuracy: 0.8634 - loss: 0.8755
# Epoch 42/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - accuracy: 0.9127 - loss: 0.7684
# Epoch 43/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - accuracy: 0.9350 - loss: 0.7331
# Epoch 44/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - accuracy: 0.9351 - loss: 0.6667
# Epoch 45/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - accuracy: 0.9268 - loss: 0.6816
# Epoch 46/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - accuracy: 0.9461 - loss: 0.6029
# Epoch 47/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - accuracy: 0.9317 - loss: 0.6005
# Epoch 48/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - accuracy: 0.9302 - loss: 0.6041
# Epoch 49/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - accuracy: 0.9647 - loss: 0.5400
# Epoch 50/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - accuracy: 0.9530 - loss: 0.5191
# Epoch 51/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - accuracy: 0.9606 - loss: 0.4847
# Epoch 52/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - accuracy: 0.9603 - loss: 0.4652
# Epoch 53/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - accuracy: 0.9602 - loss: 0.4475
# Epoch 54/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - accuracy: 0.9589 - loss: 0.4482
# Epoch 55/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - accuracy: 0.9606 - loss: 0.3937
# Epoch 56/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - accuracy: 0.9660 - loss: 0.3982
# Epoch 57/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - accuracy: 0.9620 - loss: 0.3912
# Epoch 58/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - accuracy: 0.9549 - loss: 0.3885
# Epoch 59/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - accuracy: 0.9655 - loss: 0.3539
# Epoch 60/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - accuracy: 0.9653 - loss: 0.3592
# Epoch 61/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - accuracy: 0.9718 - loss: 0.3362
# Epoch 62/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - accuracy: 0.9782 - loss: 0.2940
# Epoch 63/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - accuracy: 0.9579 - loss: 0.3375
# Epoch 64/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - accuracy: 0.9614 - loss: 0.3222
# Epoch 65/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - accuracy: 0.9623 - loss: 0.2988
# Epoch 66/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - accuracy: 0.9660 - loss: 0.2977
# Epoch 67/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - accuracy: 0.9628 - loss: 0.2839
# Epoch 68/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - accuracy: 0.9658 - loss: 0.2865
# Epoch 69/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - accuracy: 0.9686 - loss: 0.2640
# Epoch 70/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - accuracy: 0.9707 - loss: 0.2421
# Epoch 71/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - accuracy: 0.9671 - loss: 0.2527
# Epoch 72/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - accuracy: 0.9636 - loss: 0.2469
# Epoch 73/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - accuracy: 0.9682 - loss: 0.2443
# Epoch 74/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - accuracy: 0.9776 - loss: 0.2049
# Epoch 75/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - accuracy: 0.9568 - loss: 0.2481
# Epoch 76/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - accuracy: 0.9564 - loss: 0.2611
# Epoch 77/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - accuracy: 0.9686 - loss: 0.2269
# Epoch 78/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - accuracy: 0.9656 - loss: 0.2183
# Epoch 79/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - accuracy: 0.9706 - loss: 0.2130
# Epoch 80/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - accuracy: 0.9749 - loss: 0.1901
# Epoch 81/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - accuracy: 0.9681 - loss: 0.1905
# Epoch 82/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - accuracy: 0.9755 - loss: 0.1874
# Epoch 83/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - accuracy: 0.9714 - loss: 0.1895
# Epoch 84/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - accuracy: 0.9812 - loss: 0.1592
# Epoch 85/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - accuracy: 0.9746 - loss: 0.1698
# Epoch 86/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - accuracy: 0.9795 - loss: 0.1511
# Epoch 87/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - accuracy: 0.9826 - loss: 0.1461
# Epoch 88/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - accuracy: 0.9734 - loss: 0.1591
# Epoch 89/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - accuracy: 0.9756 - loss: 0.1691
# Epoch 90/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - accuracy: 0.9641 - loss: 0.1859
# Epoch 91/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - accuracy: 0.9711 - loss: 0.1590
# Epoch 92/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - accuracy: 0.9768 - loss: 0.1513
# Epoch 93/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - accuracy: 0.9719 - loss: 0.1512
# Epoch 94/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - accuracy: 0.9831 - loss: 0.1267
# Epoch 95/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - accuracy: 0.9788 - loss: 0.1356
# Epoch 96/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - accuracy: 0.9711 - loss: 0.1443
# Epoch 97/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - accuracy: 0.9710 - loss: 0.1572
# Epoch 98/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - accuracy: 0.9733 - loss: 0.1263
# Epoch 99/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - accuracy: 0.9707 - loss: 0.1427
# Epoch 100/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - accuracy: 0.9679 - loss: 0.1511

# %%
import time
import numpy as np
text = "the brainstem "

for i in range(100):
  # tokenize
  token_text = tokenizer.texts_to_sequences([text])[0]
  # padding
  padded_token_text = pad_sequences([token_text], maxlen=56, padding='pre')
  # predict
  pos = np.argmax(model.predict(padded_token_text))

  for word,index in tokenizer.word_index.items():
    if index == pos:
      text = text + " " + word
      print(text)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 358ms/step
# the brainstem  also
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# the brainstem  also processes
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# the brainstem  also processes incoming
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# the brainstem  also processes incoming sensory
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# the brainstem  also processes incoming sensory information
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# the brainstem  also processes incoming sensory information however
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# the brainstem  also processes incoming sensory information however all
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# the brainstem  also processes incoming sensory information however all of
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# the brainstem  also processes incoming sensory information however all of the
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# the brainstem  also processes incoming sensory information however all of the information
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# the brainstem  also processes incoming sensory information however all of the information processed
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# the brainstem  also processes incoming sensory information however all of the information processed by
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# the brainstem  also processes incoming sensory information however all of the information processed by the
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# the brainstem  also processes incoming sensory information however all of the information processed by the hypothalamus
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# the brainstem  also processes incoming sensory information however all of the information processed by the hypothalamus is
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# the brainstem  also processes incoming sensory information however all of the information processed by the hypothalamus is derived
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# the brainstem  also processes incoming sensory information however all of the information processed by the hypothalamus is derived from
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# the brainstem  also processes incoming sensory information however all of the information processed by the hypothalamus is derived from the
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# the brainstem  also processes incoming sensory information however all of the information processed by the hypothalamus is derived from the hypothalamus
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# the brainstem  also processes incoming sensory information however all of the information processed by the hypothalamus is derived from the hypothalamus is
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# the brainstem  also processes incoming sensory information however all of the information processed by the hypothalamus is derived from the hypothalamus is derived
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# the brainstem  also processes incoming sensory information however all of the information processed by the hypothalamus is derived from the hypothalamus is derived from
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# the brainstem  also processes incoming sensory information however all of the information processed by the hypothalamus is derived from the hypothalamus is derived from the
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# the brainstem  also processes incoming sensory information however all of the information processed by the hypothalamus is derived from the hypothalamus is derived from the autonomic
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# the brainstem  also processes incoming sensory information however all of the information processed by the hypothalamus is derived from the hypothalamus is derived from the autonomic nervous
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# the brainstem  also processes incoming sensory information however all of the information processed by the hypothalamus is derived from the hypothalamus is derived from the autonomic nervous system
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# the brainstem  also processes incoming sensory information however all of the information processed by the hypothalamus is derived from the hypothalamus is derived from the autonomic nervous system ans
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# the brainstem  also processes incoming sensory information however all of the information processed by the hypothalamus is derived from the hypothalamus is derived from the autonomic nervous system ans ans
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# the brainstem  also processes incoming sensory information however all of the information processed by the hypothalamus is derived from the hypothalamus is derived from the autonomic nervous system ans ans ans
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# the brainstem  also processes incoming sensory information however all of the information processed by the hypothalamus is derived from the hypothalamus is derived from the autonomic nervous system ans ans ans ans
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# the brainstem  also processes incoming sensory information however all of the information processed by the hypothalamus is derived from the hypothalamus is derived from the autonomic nervous system ans ans ans ans and
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# the brainstem  also processes incoming sensory information however all of the information processed by the hypothalamus is derived from the hypothalamus is derived from the autonomic nervous system ans ans ans ans and balance
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# the brainstem  also processes incoming sensory information however all of the information processed by the hypothalamus is derived from the hypothalamus is derived from the autonomic nervous system ans ans ans ans and balance as
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# the brainstem  also processes incoming sensory information however all of the information processed by the hypothalamus is derived from the hypothalamus is derived from the autonomic nervous system ans ans ans ans and balance as breathing
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# the brainstem  also processes incoming sensory information however all of the information processed by the hypothalamus is derived from the hypothalamus is derived from the autonomic nervous system ans ans ans ans and balance as breathing blood
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# the brainstem  also processes incoming sensory information however all of the information processed by the hypothalamus is derived from the hypothalamus is derived from the autonomic nervous system ans ans ans ans and balance as breathing blood pressure
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# the brainstem  also processes incoming sensory information however all of the information processed by the hypothalamus is derived from the hypothalamus is derived from the autonomic nervous system ans ans ans ans and balance as breathing blood pressure cardiac
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# the brainstem  also processes incoming sensory information however all of the information processed by the hypothalamus is derived from the hypothalamus is derived from the autonomic nervous system ans ans ans ans and balance as breathing blood pressure cardiac rhythms
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# the brainstem  also processes incoming sensory information however all of the information processed by the hypothalamus is derived from the hypothalamus is derived from the autonomic nervous system ans ans ans ans and balance as breathing blood pressure cardiac rhythms and
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# the brainstem  also processes incoming sensory information however all of the information processed by the hypothalamus is derived from the hypothalamus is derived from the autonomic nervous system ans ans ans ans and balance as breathing blood pressure cardiac rhythms and swallowing
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# the brainstem  also processes incoming sensory information however all of the information processed by the hypothalamus is derived from the hypothalamus is derived from the autonomic nervous system ans ans ans ans and balance as breathing blood pressure cardiac rhythms and swallowing swallowing
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# the brainstem  also processes incoming sensory information however all of the information processed by the hypothalamus is derived from the hypothalamus is derived from the autonomic nervous system ans ans ans ans and balance as breathing blood pressure cardiac rhythms and swallowing swallowing swallowing
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# the brainstem  also processes incoming sensory information however all of the information processed by the hypothalamus is derived from the hypothalamus is derived from the autonomic nervous system ans ans ans ans and balance as breathing blood pressure cardiac rhythms and swallowing swallowing swallowing for
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# the brainstem  also processes incoming sensory information however all of the information processed by the hypothalamus is derived from the hypothalamus is derived from the autonomic nervous system ans ans ans ans and balance as breathing blood pressure cardiac rhythms and swallowing swallowing swallowing for processing
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# the brainstem  also processes incoming sensory information however all of the information processed by the hypothalamus is derived from the hypothalamus is derived from the autonomic nervous system ans ans ans ans and balance as breathing blood pressure cardiac rhythms and swallowing swallowing swallowing for processing for
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# the brainstem  also processes incoming sensory information however all of the information processed by the hypothalamus is derived from the hypothalamus is derived from the autonomic nervous system ans ans ans ans and balance as breathing blood pressure cardiac rhythms and swallowing swallowing swallowing for processing for processing
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# the brainstem  also processes incoming sensory information however all of the information processed by the hypothalamus is derived from the hypothalamus is derived from the autonomic nervous system ans ans ans ans and balance as breathing blood pressure cardiac rhythms and swallowing swallowing swallowing for processing for processing for
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# the brainstem  also processes incoming sensory information however all of the information processed by the hypothalamus is derived from the hypothalamus is derived from the autonomic nervous system ans ans ans ans and balance as breathing blood pressure cardiac rhythms and swallowing swallowing swallowing for processing for processing for sensory
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# the brainstem  also processes incoming sensory information however all of the information processed by the hypothalamus is derived from the hypothalamus is derived from the autonomic nervous system ans ans ans ans and balance as breathing blood pressure cardiac rhythms and swallowing swallowing swallowing for processing for processing for sensory sensory
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# the brainstem  also processes incoming sensory information however all of the information processed by the hypothalamus is derived from the hypothalamus is derived from the autonomic nervous system ans ans ans ans and balance as breathing blood pressure cardiac rhythms and swallowing swallowing swallowing for processing for processing for sensory sensory information
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# the brainstem  also processes incoming sensory information however all of the information processed by the hypothalamus is derived from the hypothalamus is derived from the autonomic nervous system ans ans ans ans and balance as breathing blood pressure cardiac rhythms and swallowing swallowing swallowing for processing for processing for sensory sensory information processed
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# the brainstem  also processes incoming sensory information however all of the information processed by the hypothalamus is derived from the hypothalamus is derived from the autonomic nervous system ans ans ans ans and balance as breathing blood pressure cardiac rhythms and swallowing swallowing swallowing for processing for processing for sensory sensory information processed by
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# the brainstem  also processes incoming sensory information however all of the information processed by the hypothalamus is derived from the hypothalamus is derived from the autonomic nervous system ans ans ans ans and balance as breathing blood pressure cardiac rhythms and swallowing swallowing swallowing for processing for processing for sensory sensory information processed by the
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# the brainstem  also processes incoming sensory information however all of the information processed by the hypothalamus is derived from the hypothalamus is derived from the autonomic nervous system ans ans ans ans and balance as breathing blood pressure cardiac rhythms and swallowing swallowing swallowing for processing for processing for sensory sensory information processed by the facial
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# the brainstem  also processes incoming sensory information however all of the information processed by the hypothalamus is derived from the hypothalamus is derived from the autonomic nervous system ans ans ans ans and balance as breathing blood pressure cardiac rhythms and swallowing swallowing swallowing for processing for processing for sensory sensory information processed by the facial nerves
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# the brainstem  also processes incoming sensory information however all of the information processed by the hypothalamus is derived from the hypothalamus is derived from the autonomic nervous system ans ans ans ans and balance as breathing blood pressure cardiac rhythms and swallowing swallowing swallowing for processing for processing for sensory sensory information processed by the facial nerves nerves
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# the brainstem  also processes incoming sensory information however all of the information processed by the hypothalamus is derived from the hypothalamus is derived from the autonomic nervous system ans ans ans ans and balance as breathing blood pressure cardiac rhythms and swallowing swallowing swallowing for processing for processing for sensory sensory information processed by the facial nerves nerves nerves
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# the brainstem  also processes incoming sensory information however all of the information processed by the hypothalamus is derived from the hypothalamus is derived from the autonomic nervous system ans ans ans ans and balance as breathing blood pressure cardiac rhythms and swallowing swallowing swallowing for processing for processing for sensory sensory information processed by the facial nerves nerves nerves for
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# the brainstem  also processes incoming sensory information however all of the information processed by the hypothalamus is derived from the hypothalamus is derived from the autonomic nervous system ans ans ans ans and balance as breathing blood pressure cardiac rhythms and swallowing swallowing swallowing for processing for processing for sensory sensory information processed by the facial nerves nerves nerves for processing
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# the brainstem  also processes incoming sensory information however all of the information processed by the hypothalamus is derived from the hypothalamus is derived from the autonomic nervous system ans ans ans ans and balance as breathing blood pressure cardiac rhythms and swallowing swallowing swallowing for processing for processing for sensory sensory information processed by the facial nerves nerves nerves for processing for
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# the brainstem  also processes incoming sensory information however all of the information processed by the hypothalamus is derived from the hypothalamus is derived from the autonomic nervous system ans ans ans ans and balance as breathing blood pressure cardiac rhythms and swallowing swallowing swallowing for processing for processing for sensory sensory information processed by the facial nerves nerves nerves for processing for processing
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# the brainstem  also processes incoming sensory information however all of the information processed by the hypothalamus is derived from the hypothalamus is derived from the autonomic nervous system ans ans ans ans and balance as breathing blood pressure cardiac rhythms and swallowing swallowing swallowing for processing for processing for sensory sensory information processed by the facial nerves nerves nerves for processing for processing well
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# the brainstem  also processes incoming sensory information however all of the information processed by the hypothalamus is derived from the hypothalamus is derived from the autonomic nervous system ans ans ans ans and balance as breathing blood pressure cardiac rhythms and swallowing swallowing swallowing for processing for processing for sensory sensory information processed by the facial nerves nerves nerves for processing for processing well as
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# the brainstem  also processes incoming sensory information however all of the information processed by the hypothalamus is derived from the hypothalamus is derived from the autonomic nervous system ans ans ans ans and balance as breathing blood pressure cardiac rhythms and swallowing swallowing swallowing for processing for processing for sensory sensory information processed by the facial nerves nerves nerves for processing for processing well as all
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# the brainstem  also processes incoming sensory information however all of the information processed by the hypothalamus is derived from the hypothalamus is derived from the autonomic nervous system ans ans ans ans and balance as breathing blood pressure cardiac rhythms and swallowing swallowing swallowing for processing for processing for sensory sensory information processed by the facial nerves nerves nerves for processing for processing well as all sensory
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# the brainstem  also processes incoming sensory information however all of the information processed by the hypothalamus is derived from the hypothalamus is derived from the autonomic nervous system ans ans ans ans and balance as breathing blood pressure cardiac rhythms and swallowing swallowing swallowing for processing for processing for sensory sensory information processed by the facial nerves nerves nerves for processing for processing well as all sensory information
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# the brainstem  also processes incoming sensory information however all of the information processed by the hypothalamus is derived from the hypothalamus is derived from the autonomic nervous system ans ans ans ans and balance as breathing blood pressure cardiac rhythms and swallowing swallowing swallowing for processing for processing for sensory sensory information processed by the facial nerves nerves nerves for processing for processing well as all sensory information processed
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# the brainstem  also processes incoming sensory information however all of the information processed by the hypothalamus is derived from the hypothalamus is derived from the autonomic nervous system ans ans ans ans and balance as breathing blood pressure cardiac rhythms and swallowing swallowing swallowing for processing for processing for sensory sensory information processed by the facial nerves nerves nerves for processing for processing well as all sensory information processed by
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# the brainstem  also processes incoming sensory information however all of the information processed by the hypothalamus is derived from the hypothalamus is derived from the autonomic nervous system ans ans ans ans and balance as breathing blood pressure cardiac rhythms and swallowing swallowing swallowing for processing for processing for sensory sensory information processed by the facial nerves nerves nerves for processing for processing well as all sensory information processed by the
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# the brainstem  also processes incoming sensory information however all of the information processed by the hypothalamus is derived from the hypothalamus is derived from the autonomic nervous system ans ans ans ans and balance as breathing blood pressure cardiac rhythms and swallowing swallowing swallowing for processing for processing for sensory sensory information processed by the facial nerves nerves nerves for processing for processing well as all sensory information processed by the brain
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# the brainstem  also processes incoming sensory information however all of the information processed by the hypothalamus is derived from the hypothalamus is derived from the autonomic nervous system ans ans ans ans and balance as breathing blood pressure cardiac rhythms and swallowing swallowing swallowing for processing for processing for sensory sensory information processed by the facial nerves nerves nerves for processing for processing well as all sensory information processed by the brain is
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# the brainstem  also processes incoming sensory information however all of the information processed by the hypothalamus is derived from the hypothalamus is derived from the autonomic nervous system ans ans ans ans and balance as breathing blood pressure cardiac rhythms and swallowing swallowing swallowing for processing for processing for sensory sensory information processed by the facial nerves nerves nerves for processing for processing well as all sensory information processed by the brain is the
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# the brainstem  also processes incoming sensory information however all of the information processed by the hypothalamus is derived from the hypothalamus is derived from the autonomic nervous system ans ans ans ans and balance as breathing blood pressure cardiac rhythms and swallowing swallowing swallowing for processing for processing for sensory sensory information processed by the facial nerves nerves nerves for processing for processing well as all sensory information processed by the brain is the cerebrum
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[22], line 17
#      15 text = text + " " + word
#      16 print(text)
# ---> 17 time.sleep(2)
#
# KeyboardInterrupt:
